# %%
import pandas as pd
import sqlite3
import numpy as np
import seaborn as sns

# %%
con = sqlite3.connect("DSCI6002_prj1_data.db")

execute = con.execute('SELECT * FROM prj1')

# %%
data=pd.DataFrame(execute.fetchall(),columns=['index','EdLevel','Score'])

# %%
#understanding the data
data.head()
# Out:
#    index       EdLevel  Score
# 0      0  Less than HS   26.0
# 1      1  Less than HS   43.8
# 2      2  Less than HS   34.4
# 3      3  Less than HS   76.2
# 4      4  Less than HS    0.2

# %%
data.tail()
# Out:
#       index Less than HS    45
# 1166   1166     Graduate  52.7
# 1167   1167     Graduate  59.8
# 1168   1168     Graduate  54.1
# 1169   1169     Graduate  39.9
# 1170   1170     Graduate  58.2

# %%
data.shape
# Out:
# (1171, 3)

# %%
data.describe()
# Out:
#              index        Score
# count  1171.000000  1160.000000
# mean    585.000000    40.726724
# std     338.182889    15.166281
# min       0.000000     0.200000
# 25%     292.500000    30.300000
# 50%     585.000000    41.000000
# 75%     877.500000    51.325000
# max    1170.000000    86.400000

# %%
data.columns
# Out:
# Index(['index', 'EdLevel', 'Score'], dtype='object')

# %%
#checking for unique values
data.nunique()
# Out:
# index      1171
# EdLevel       5
# Score       517
# dtype: int64

# %%
data['EdLevel'].unique()
# Out:
# array(['Less than HS', 'HS', 'Jr Coll', "Bachelor's", 'Graduate'],
#       dtype=object)

# %%
#cleaning the dataset
data.isnull().sum()
# Out:
# index       0
# EdLevel     0
# Score      11
# dtype: int64

# %%
#relationship analysis
corelation=data.corr()
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x= "Score",hue= "EdLevel",y="index",data=data)

# %%
sns.displot(data['EdLevel'])

# %%
sns.catplot(x='Score',kind="box",data=data)
